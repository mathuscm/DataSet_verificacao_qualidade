# %% [markdown]
# # Chamando o módulo DataQuality.py

# %%
from dataquality import DataQuality
import pandas as pd 

# Read the DataFrame:
df = pd.read_csv('Forbes_Richest_Atheletes_1990_2020.csv')

# Iniciate the Class dataquality with the DataFrame:
dq = DataQuality(df)

# %% [markdown]
# ## Check Methods:

# %% [markdown]
# ### 1. Check Nulls

# %%
# Check null values:
print("\nNull values for column:")
display(dq.check_nulls())
#dq.check_nulls()
#null_values = dq.check_nulls()
# Out:
# Null values for column:
# S.NO                     0
# Name                     0
# Nationality              0
# Current Rank             0
# Previous Year Rank      24
# Sport                    0
# Year                     0
# earnings ($ million)     0
# dtype: int64

# %% [markdown]
# ### 2. Check Duplicated

# %%
# Check duplicated lines:
print(f"\nDuplicated lines: {dq.check_duplicates()}")
# Out:
# Duplicated lines: 0

# %% [markdown]
# ### 3. Check Numeric Columns

# %%
# Check numeric columns:
print("\nNumeric columns:")
print(dq.check_numeric_cols())
# Out:
# Numeric columns:
# Index(['S.NO', 'Current Rank', 'Year', 'earnings ($ million)'], dtype='object')

# %% [markdown]
# ### 4. Check Data Types

# %%
# Check Data Types:
print("\nData Types:")
print(dq.check_data_types())
# Out:
# Data Types:
# S.NO                      int64
# Name                     object
# Nationality              object
# Current Rank              int64
# Previous Year Rank       object
# Sport                    object
# Year                      int64
# earnings ($ million)    float64
# dtype: object

# %% [markdown]
# ### 5. Check Unique Values

# %%
# Check Unique Values:
print("\nUnique Values:")
print(dq.check_unique_values())
# Out:
# Unique Values:
# S.NO                    301
# Name                     82
# Nationality              22
# Current Rank             10
# Previous Year Rank       36
# Sport                    29
# Year                     30
# earnings ($ million)    198
# dtype: int64

# %% [markdown]
# ### 6. Describe Data

# %%
# Check Describe Data:
print("\nDescribe Data:")
display(dq.describe_data())
# Out:
# Describe Data:
#              S.NO  Current Rank         Year  earnings ($ million)
# count  301.000000    301.000000   301.000000            301.000000
# mean   151.000000      5.448505  2005.122924             45.516279
# std     87.035433      2.850995     9.063563             33.525337
# min      1.000000      1.000000  1990.000000              8.100000
# 25%     76.000000      3.000000  1997.000000             24.000000
# 50%    151.000000      5.000000  2005.000000             39.000000
# 75%    226.000000      8.000000  2013.000000             59.400000
# max    301.000000     10.000000  2020.000000            300.000000

# %% [markdown]
# ### 7. Missing Values Summary

# %%
# Missing Values Summary:
print("\nMissing Values:")
display(dq.missing_values_summary())
# Out:
# Missing Values:
#                       Missing Values  Percentage (%)
# S.NO                               0        0.000000
# Name                               0        0.000000
# Nationality                        0        0.000000
# Current Rank                       0        0.000000
# Previous Year Rank                24        7.973422
# Sport                              0        0.000000
# Year                               0        0.000000
# earnings ($ million)               0        0.000000

# %% [markdown]
# ### 8. Numeric Columns

# %%
dq.numeric_cols()
# Out:
#      S.NO  Current Rank  Year  earnings ($ million)
# 0       1             1  1990                  28.6
# 1       2             2  1990                  26.0
# 2       3             3  1990                  13.0
# 3       4             4  1990                  10.0
# 4       5             5  1990                   9.0
# ..    ...           ...   ...                   ...
# 296   297             6  2020                  74.4
# 297   298             7  2020                  63.9
# 298   299             8  2020                  62.3
# 299   300             9  2020                  60.5
# 300   301            10  2020                  59.1
#
# [301 rows x 4 columns]

# %% [markdown]
# ### 9. Outlier Summary

# %%
dq.outlier_summary()
# Out:
# Summary  of Outliers by Column:
# earnings ($ million)    5
# dtype: int64

# %% [markdown]
# ### 10. General Info

# %%
dq.general_info()
# Out:
# General info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.NO                  301 non-null    int64
#  1   Name                  301 non-null    object
#  2   Nationality           301 non-null    object
#  3   Current Rank          301 non-null    int64
#  4   Previous Year Rank    277 non-null    object
#  5   Sport                 301 non-null    object
#  6   Year                  301 non-null    int64
#  7   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 18.9+ KB
# None

# %% [markdown]
# ## Visualization Methods

# %% [markdown]
# ### 1. Plot nulls

# %%
# Check null values and plot a bar graph:
dq.plot_nulls()

# %% [markdown]
# ### 2. Plot Data Distribution

# %%
# Check the numeric data distribution and plot a graph:
dq.plot_data_distribution()

# %% [markdown]
# ### 3. Plot BoxPlot

# %%
# Generate boxplot to detect outliers (numeric_cols = None, all numeric columns will be consider to plot):
#dq.plot_boxplot(numeric_cols=['Current Rank','earnings ($ million)'])
#dq.plot_boxplot(numeric_cols='Current Rank, earnings ($ million)')
dq.plot_boxplot()

# %% [markdown]
# ### 4. Correlation Matrix

# %%
dq.correlation_matrix()

# %% [markdown]
# ### 5. Temporal Analysis

# %%
dq.temporal_analysis()

# %% [markdown]
# ### 6. Plot Numeric Distribution

# %%
dq.plot_numeric_dist()
# Out:
# Numeric Columns Distribution:

# %% [markdown]
# ## General Report

# %%
dq.general_report()
# Out:
# Null values for column:
# S.NO                     0
# Name                     0
# Nationality              0
# Current Rank             0
# Previous Year Rank      24
# Sport                    0
# Year                     0
# earnings ($ million)     0
# dtype: int64
# ------------------------------------------------ // ------------------------------------------------
#
#
#
# Duplicated lines: 0
# ------------------------------------------------ // ------------------------------------------------
#
#
#
# Data Types:
# S.NO                      int64
# Name                     object
# Nationality              object
# Current Rank              int64
# Previous Year Rank       object
# Sport                    object
# Year                      int64
# earnings ($ million)    float64
# dtype: object
# ------------------------------------------------ // ------------------------------------------------
#
#
#
# Unique Values:
# S.NO                    301
# ...
